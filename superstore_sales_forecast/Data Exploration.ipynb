# %% [markdown]
# # Imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# # Dataset Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
df.describe(include = 'all')
# Out:
#              Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# count   9800.000000            9800        9800        9800            9800
# unique          NaN            4922        1230        1326               4
# top             NaN  CA-2018-100111  05/09/2017  26/09/2018  Standard Class
# freq            NaN              14          38          34            5859
# mean    4900.500000             NaN         NaN         NaN             NaN
# std     2829.160653             NaN         NaN         NaN             NaN
# min        1.000000             NaN         NaN         NaN             NaN
# 25%     2450.750000             NaN         NaN         NaN             NaN
# 50%     4900.500000             NaN         NaN         NaN             NaN
# 75%     7350.250000             NaN         NaN         NaN             NaN
# max     9800.000000             NaN         NaN         NaN             NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df[df['Postal Code'].isnull()]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2234    2235  CA-2018-104066  05/12/2018  10/12/2018  Standard Class
# 5274    5275  CA-2016-162887  07/11/2016  09/11/2016    Second Class
# 8798    8799  US-2017-150140  06/04/2017  10/04/2017  Standard Class
# 9146    9147  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9147    9148  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9148    9149  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9386    9387  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9387    9388  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9388    9389  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9389    9390  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country        City  \
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%d/%m/%Y')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='%d/%m/%Y')

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  9800.000000                           9800
# mean   4900.500000  2017-05-01 05:13:51.673469440
# min       1.000000            2015-01-03 00:00:00
# 25%    2450.750000            2016-05-24 00:00:00
# 50%    4900.500000            2017-06-26 00:00:00
# 75%    7350.250000            2018-05-15 00:00:00
# max    9800.000000            2018-12-30 00:00:00
# std    2829.160653                            NaN
#
#                            Ship Date   Postal Code         Sales
# count                           9800   9789.000000   9800.000000
# mean   2017-05-05 04:17:52.653061120  55273.322403    230.769059
# min              2015-01-07 00:00:00   1040.000000      0.444000
# 25%              2016-05-27 18:00:00  23223.000000     17.248000
# 50%              2017-06-29 00:00:00  58103.000000     54.490000
# 75%              2018-05-19 00:00:00  90008.000000    210.605000
# ...

# %%
df.value_counts('Ship Mode')
# Out:
# Ship Mode
# Standard Class    5859
# Second Class      1902
# First Class       1501
# Same Day           538
# Name: count, dtype: int64

# %%
df.value_counts('Segment')
# Out:
# Segment
# Consumer       5101
# Corporate      2953
# Home Office    1746
# Name: count, dtype: int64

# %%
df.value_counts('Country')
# Out:
# Country
# United States    9800
# Name: count, dtype: int64

# %%
df.value_counts('City')
# Out:
# City
# New York City    891
# Los Angeles      728
# Philadelphia     532
# San Francisco    500
# Seattle          426
#                 ...
# Vacaville          1
# Baytown            1
# Antioch            1
# Abilene            1
# Aberdeen           1
# Name: count, Length: 529, dtype: int64

# %%
df.value_counts('State')
# Out:
# State
# California              1946
# New York                1097
# Texas                    973
# Pennsylvania             582
# Washington               504
# Illinois                 483
# Ohio                     454
# Florida                  373
# Michigan                 253
# North Carolina           247
# Virginia                 224
# Arizona                  223
# Tennessee                183
# Colorado                 179
# Georgia                  177
# Kentucky                 137
# Indiana                  135
# Massachusetts            135
# New Jersey               122
# Oregon                   122
# Wisconsin                105
# Maryland                 105
# Delaware                  93
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              55
# Utah                      53
# Mississippi               53
# ...

# %%
df.value_counts('Region')
# Out:
# Region
# West       3140
# East       2785
# Central    2277
# South      1598
# Name: count, dtype: int64

# %%
df.value_counts('Category')
# Out:
# Category
# Office Supplies    5909
# Furniture          2078
# Technology         1813
# Name: count, dtype: int64

# %%
df.value_counts('Sub-Category')
# Out:
# Sub-Category
# Binders        1492
# Paper          1338
# Furnishings     931
# Phones          876
# Storage         832
# Art             785
# Accessories     756
# Chairs          607
# Appliances      459
# Labels          357
# Tables          314
# Envelopes       248
# Bookcases       226
# Fasteners       214
# Supplies        184
# Machines        115
# Copiers          66
# Name: count, dtype: int64

# %%
sns.boxplot(data=df, x='Sales')
plt.title('Sales Boxplot')
plt.show()

# %%
df.hist('Sales')
plt.title('Sales Histplot')
plt.show()

# %% [markdown]
# # Time Series Data

# %%
df_transaction = df[['Order Date', 'Sales']].copy()

# %%
df_transaction['month'] = df['Order Date'].dt.month
df_transaction['year'] = df['Order Date'].dt.year
df_transaction['yearmonth'] = df['Order Date'].dt.to_period('M')

# %%
df_sales_per_month = df_transaction.groupby('yearmonth')['Sales'].sum().reset_index()

# %%
df_sales_per_month['yearmonth'] = df_sales_per_month['yearmonth'].dt.to_timestamp()

# %%
df_sales_per_month
# Out:
#     yearmonth        Sales
# 0  2015-01-01   14205.7070
# 1  2015-02-01    4519.8920
# 2  2015-03-01   55205.7970
# 3  2015-04-01   27906.8550
# 4  2015-05-01   23644.3030
# 5  2015-06-01   34322.9356
# 6  2015-07-01   33781.5430
# 7  2015-08-01   27117.5365
# 8  2015-09-01   81623.5268
# 9  2015-10-01   31453.3930
# 10 2015-11-01   77907.6607
# 11 2015-12-01   68167.0585
# 12 2016-01-01   18066.9576
# 13 2016-02-01   11951.4110
# 14 2016-03-01   32339.3184
# 15 2016-04-01   34154.4685
# 16 2016-05-01   29959.5305
# 17 2016-06-01   23599.3740
# 18 2016-07-01   28608.2590
# 19 2016-08-01   36818.3422
# 20 2016-09-01   63133.6060
# 21 2016-10-01   31011.7375
# 22 2016-11-01   75249.3995
# 23 2016-12-01   74543.6012
# 24 2017-01-01   18542.4910
# 25 2017-02-01   22978.8150
# 26 2017-03-01   51165.0590
# 27 2017-04-01   38679.7670
# 28 2017-05-01   56656.9080
# 29 2017-06-01   39724.4860
# 30 2017-07-01   38320.7830
# 31 2017-08-01   30542.2003
# 32 2017-09-01   69193.3909
# ...

# %%
df_sales_per_month.dtypes
# Out:
# yearmonth    datetime64[ns]
# Sales               float64
# dtype: object

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=df_sales_per_month['yearmonth'], y=df_sales_per_month['Sales'], marker='o')
plt.show()

# %% [markdown]
# # Train Test Split

# %%
df_sales_per_month
# Out:
#     yearmonth        Sales
# 0  2015-01-01   14205.7070
# 1  2015-02-01    4519.8920
# 2  2015-03-01   55205.7970
# 3  2015-04-01   27906.8550
# 4  2015-05-01   23644.3030
# 5  2015-06-01   34322.9356
# 6  2015-07-01   33781.5430
# 7  2015-08-01   27117.5365
# 8  2015-09-01   81623.5268
# 9  2015-10-01   31453.3930
# 10 2015-11-01   77907.6607
# 11 2015-12-01   68167.0585
# 12 2016-01-01   18066.9576
# 13 2016-02-01   11951.4110
# 14 2016-03-01   32339.3184
# 15 2016-04-01   34154.4685
# 16 2016-05-01   29959.5305
# 17 2016-06-01   23599.3740
# 18 2016-07-01   28608.2590
# 19 2016-08-01   36818.3422
# 20 2016-09-01   63133.6060
# 21 2016-10-01   31011.7375
# 22 2016-11-01   75249.3995
# 23 2016-12-01   74543.6012
# 24 2017-01-01   18542.4910
# 25 2017-02-01   22978.8150
# 26 2017-03-01   51165.0590
# 27 2017-04-01   38679.7670
# 28 2017-05-01   56656.9080
# 29 2017-06-01   39724.4860
# 30 2017-07-01   38320.7830
# 31 2017-08-01   30542.2003
# 32 2017-09-01   69193.3909
# ...

# %%
train = df_sales_per_month.loc[df_sales_per_month['yearmonth'] < '2018-01-01'].copy()

test = df_sales_per_month.loc[df_sales_per_month['yearmonth'] >= '2018-01-01'].copy()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=train['yearmonth'], y=train['Sales'], marker='o', color='blue')
sns.lineplot(x=test['yearmonth'], y=test['Sales'], marker='o', color='orange')
plt.show()

# %% [markdown]
# # Notes

# %% [markdown]
# The dataset isn't originally ready for time series prediction. The dataset has a collection of sales of the store. We need to convert this data into a series format, originally we have a transcational format
#
# In terms of missing values, there are only 11 postal codes missing which do not impact the time series
#
# We have data from 2015-01 until 2018-12
#
# I will try to predict the montly sales and if the results are good, I will go for a more detailed prediction like a weekly prediction. I will separate training from test like this:
# Training -> 2015-01 until 2017-12
# Testing -> 2018-01 until 2018-12
