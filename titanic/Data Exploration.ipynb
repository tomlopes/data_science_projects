# %% [markdown]
# # Imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df['PassengerId'] = df['PassengerId'].astype('category')
df['Survived'] = df['Survived'].astype('category')
df['Pclass'] = df['Pclass'].astype('category')
df['Sex'] = df['Sex'].astype('category')
df['Embarked'] = df['Embarked'].astype('category')

# %%
df.dtypes
# Out:
# PassengerId    category
# Survived       category
# Pclass         category
# Name             object
# Sex            category
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket           object
# Fare            float64
# Cabin            object
# Embarked       category
# dtype: object

# %% [markdown]
# # Dataset Summary

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    category
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    category
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    category
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    category
# dtypes: category(5), float64(2), int64(2), object(3)
# memory usage: 93.8+ KB

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df.describe(include = 'all')
# Out:
#         PassengerId  Survived  Pclass                 Name   Sex         Age  \
# count         891.0     891.0   891.0                  891   891  891.000000
# unique        891.0       2.0     3.0                  891     2         NaN
# top           891.0       0.0     3.0  Dooley, Mr. Patrick  male         NaN
# freq            1.0     549.0   491.0                    1   577         NaN
# mean            NaN       NaN     NaN                  NaN   NaN   29.699118
# std             NaN       NaN     NaN                  NaN   NaN   13.002015
# min             NaN       NaN     NaN                  NaN   NaN    0.420000
# 25%             NaN       NaN     NaN                  NaN   NaN   22.000000
# 50%             NaN       NaN     NaN                  NaN   NaN   29.699118
# 75%             NaN       NaN     NaN                  NaN   NaN   35.000000
# max             NaN       NaN     NaN                  NaN   NaN   80.000000
#
#              SibSp       Parch  Ticket        Fare Cabin Embarked
# count   891.000000  891.000000     891  891.000000   204      891
# unique         NaN         NaN     681         NaN   147        3
# top            NaN         NaN  347082         NaN    G6        S
# freq           NaN         NaN       7         NaN     4      646
# mean      0.523008    0.381594     NaN   32.204208   NaN      NaN
# std       1.102743    0.806057     NaN   49.693429   NaN      NaN
# min       0.000000    0.000000     NaN    0.000000   NaN      NaN
# 25%       0.000000    0.000000     NaN    7.910400   NaN      NaN
# 50%       0.000000    0.000000     NaN   14.454200   NaN      NaN
# 75%       1.000000    0.000000     NaN   31.000000   NaN      NaN
# max       8.000000    6.000000     NaN  512.329200   NaN      NaN

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# # Dataset Distributions

# %%
numerical_features = ['Age', 'SibSp', 'Parch', 'Fare']
categorical_features = ['Pclass', 'Sex', 'Cabin', 'Embarked']
target = 'Survived'

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
for column in numerical_features:
    plt.figure()
    sns.boxplot(df[column])
    plt.title(f'Boxplot: {column}')
    plt.show()

# %%
for column in numerical_features:
    sns.boxplot(data = df, x = column, y = target)
    plt.show()

# %%
for column in numerical_features:
    df.hist(column)

# %%
for column in numerical_features:
    df[column].plot(kind = 'kde')
    plt.title(f'Kernel Density Estimate: {column}')
    plt.xlabel(column)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Correlations

# %%
# correlation matrix for the numeric variables
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap='coolwarm', fmt='.2f')
# Out:
# <Axes: >

# %%
from scipy.stats import f_oneway

for column in numerical_features:
    groups = [df[df[target] == i][column] for i in df[target].unique()]
    f_stat, p_value = f_oneway(*groups)
    print(f"{column}: \nF-statistic: {f_stat:.10f}, P-value: {p_value:.10f}")
# Out:
# Age:
# F-statistic: 4.3535160891, P-value: 0.0372170837
# SibSp:
# F-statistic: 1.1105722041, P-value: 0.2922439287
# Parch:
# F-statistic: 5.9634638366, P-value: 0.0147992454
# Fare:
# F-statistic: 63.0307642280, P-value: 0.0000000000

# %%
numerical_columns = df.select_dtypes(include=['float64', 'int64'])

sns.pairplot(numerical_columns, kind = 'reg')
plt.show()

# %% [markdown]
# # Categorical Features

# %%
for column in categorical_features:
    print(df[column].value_counts())
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
# Sex
# male      577
# female    314
# Name: count, dtype: int64
# Cabin
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F2             3
# D              3
#               ..
# E17            1
# A24            1
# C50            1
# B42            1
# C148           1
# Name: count, Length: 147, dtype: int64
# Embarked
# S    646
# C    168
# Q     77
# Name: count, dtype: int64

# %%
for column in categorical_features:
    sns.countplot(df[column])
    plt.show()

# %%
for column in categorical_features:
    sns.countplot(data=df, x=column, hue=target)
    plt.title(f'{column} Countplot with respect with the target')
    plt.show()

# %% [markdown]
# # Feature Relations

# %%
sns.pairplot(df, kind = 'reg')

# %%
sns.pairplot(df, hue = target, kind = 'reg')

# %%
for column in numerical_features:
    sns.scatterplot(x=df[column], y=df.index, hue=df[target])
    plt.title(f"Scatter plot of {column} colored by target")
    plt.xlabel(column)
    plt.ylabel('Index')  # Replace with any other y-variable if needed
    plt.show()

# %%
for column in numerical_columns:
    sns.violinplot(data=df, y=column, hue=target)
    plt.title(f'Violin Plot of {column} by Target')
    plt.show()

# %%
for column in numerical_columns:
    sns.histplot(df, x=column, hue=target, kde=True, multiple="layer")
    plt.title(f'Histogram of {column} by Target')
    plt.show()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# # Feature Scaling

# %% [markdown]
# # Dataset Balance

# %%
sns.countplot(df[target])
# Out:
# <Axes: xlabel='count', ylabel='Survived'>

# %% [markdown]
# # Notes

# %% [markdown]
# 1 - The dataset doesn't require balance
#
# 2 - Feature scaling should be performed
#
# 3 - Cabin and Age have null values
#
#         3.1 - Cabin can be removed from the features
#
#         3.2 - Age we should treat the null values (mean is a possibility)
#
# 4 - Not really worried with outliers. Can be tested their removal (fare seams to have some outliers)
#
# 5 - No feature seems to be correlated
#
# 6 - Female seem to have a higher survival rate compared to man. And higher fare prices also seem to have a higher survival rate. The newborn also appear to have a higher survival rate
